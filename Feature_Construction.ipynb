# %%
# Feature construction is the process of creating new, more informative, or higher-level features from raw data or existing features to improve machine learning model performance.
# Work based on domain knowledge

# %%
# Code example
import numpy as np
import pandas as pd
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
import seaborn as sns

# %%
# Import dataset
df = pd.read_csv('titanic.csv')[['Age','Pclass','SibSp','Parch','Survived']]

# %%
# Drop NA
df.dropna(inplace=True)

# %%
# Split the dataset
X = df.iloc[:,0:4]
y = df.iloc[:,-1]

# %%
# Train model
np.mean(cross_val_score(LogisticRegression(),X,y,scoring='accuracy',cv=20))
# Out:
# np.float64(0.6933333333333332)

# %%
# Applying Feature Construction
X['Family_size'] = X['SibSp'] + X['Parch'] + 1

# %%
# Create new family memeber
def myfunc(num):
    if num == 1:
        #alone
        return 0
    elif num >1 and num <=4:
        # small family
        return 1
    else:
        # large family
        return 2

# %%
X['Family_type'] = X['Family_size'].apply(myfunc)

# %%
# Drop unnecessay column
X.drop(columns=['SibSp','Parch','Family_size'],inplace=True)

# %%
# Perform model
np.mean(cross_val_score(
    LogisticRegression(),
    X,y,scoring='accuracy',
    cv=20))
# Out:
# np.float64(0.7003174603174602)

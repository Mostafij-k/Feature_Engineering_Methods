# %%
# Feature Engineering is the process of using domain knowledge to extract features from raw data.
# Feature Enigineering: Create meaningful model ready feature

# Type of Feature Enigineering:
# 1. Feature Transformtion
        # Mssing value imputation
        # Handling Categorical Variable
        # Outlier Detection
        # Feature Scaling
# 2. Feature Construction
        # Human Designed Feature
        # May or may not reduce dimensionality
        # Sometime dimension remain same
        # Sometime increase or decrease 
# 3. Feature Extraction
        # Machine derived feature
        # Decrease dimension such as 10000 feature convert into 50 PCA
# 4. Feature Selection
        # Choose best features from existing one
        # Selects subset of original features

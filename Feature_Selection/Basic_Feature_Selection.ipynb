# %%
# Feature: Feature is an input column of a datset.
# Feature Selection: It is a method to select important feature from given input dataset.

# Why we perform feature selection/Dimensionality Reduction: There are three reason
    # 1. Curse of Dimentionality
        # Certain number of feature will give best result more than that result will decrease
    # 2. Reduce Computational Complexity
    # 3. Interpretabilty
        # Low number of feature will provide better interpretation (Prediction, relationship between X and Y)
    # 4. Correlation with target
        # Drop variables that have a very low correlation with target variables
    # 5. Forward Selection
        # Identify the best vari

# %%
# Type of Feature selection:
    # 1. Filter based method
    # 2. Wrapper method
    # 3. Embeded method
    # 4. Hybrid method

# %%
# Three advantages of feature selection
    # Remove irrelevent feature
    # Easy to understand model
    # Model becomes faster

# %%
# Feature Selection Techniques:
# 1. Percentage of missing value
    # Drop variables that have high percentage of missing values
# 2. Amount of variation
    # Drop variable that have a very low variation
    # Drop variables with zero variation
# 3. Pairwise correlations
    # Many variables are often correlated with each other and hence are redundant
    # If two variable are highly correlated keeping only one will help to reduce dimentionality
    # Which variable to keep? the one that has a higher correlation with target variable
# 4. Forward Selection
    # Identify the best variables 
    # Add the next best variables into the model
    # And so on until some predefined criteria is satisfied
# 5. Backward Elimination(Recursive Feature Elimination)
    # Start with all variables included in the model
    # Drop the least useful variables
    # # And so on until some predefined criteria is satisfied
# 6. Stepwise Selection
# 7. LASSO: Least Absolute Shrinkage and Selection Operator
    # Two bard one stone: Variable Selection and Regularization
# Tree Based Method
    # Forest of Trees to evaluate the importance of features
    # Fit a number of randomized trees and use averaging to rank order features
